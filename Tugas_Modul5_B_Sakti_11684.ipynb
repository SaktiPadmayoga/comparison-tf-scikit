# %% [markdown]
# # Menggunakan Library Tensorflow

# %%
import tensorflow as tf ##jika error,  install tensorflow terlebih dahulu
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import logging
logging.getLogger('matplotlib.font_manager').disabled = True
import random

seed_value = 84
tf.random.set_seed(seed_value) 
np.random.seed(seed_value)      
random.seed(seed_value)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist  
                                                 
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
plt.figure() 
plt.imshow(train_images[0]) 
plt.colorbar() 
plt.grid(False)
plt.show()

# %%
train_images = train_images.reshape(-1, 28, 28, 1).astype('float32') / 255
test_images = test_images.reshape(-1, 28, 28, 1).astype('float32') / 255

# %%
plt.figure(figsize=(10,10)) 
for i in range(25): 
    plt.subplot(5,5,i+1) 
    plt.xticks([]) 
    plt.yticks([]) 
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary) 
    plt.xlabel(class_names[train_labels[i]]) 
plt.show()

# %%
model_tf = tf.keras.Sequential([ 
    tf.keras.layers.Input(shape=(28,28)), 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(300, activation='relu'),  
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10)
])

# %%
model_tf.compile(optimizer='adam', 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping


early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=5,
    min_delta=0.0001,
    restore_best_weights=True  
)


history = model_tf.fit(
    train_images, train_labels,
    epochs=40,
    validation_data=(test_images, test_labels),
    callbacks=[early_stopping]  
)
# Out:
# Epoch 1/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7318 - loss: 0.7361 - val_accuracy: 0.8415 - val_loss: 0.4362
# Epoch 2/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8361 - loss: 0.4522 - val_accuracy: 0.8537 - val_loss: 0.4084
# Epoch 3/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8497 - loss: 0.4114 - val_accuracy: 0.8612 - val_loss: 0.3840
# Epoch 4/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8580 - loss: 0.3915 - val_accuracy: 0.8654 - val_loss: 0.3755
# Epoch 5/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8626 - loss: 0.3745 - val_accuracy: 0.8718 - val_loss: 0.3655
# Epoch 6/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8674 - loss: 0.3605 - val_accuracy: 0.8700 - val_loss: 0.3633
# Epoch 7/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8712 - loss: 0.3499 - val_accuracy: 0.8714 - val_loss: 0.3579
# Epoch 8/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8747 - loss: 0.3418 - val_accuracy: 0.8723 - val_loss: 0.3567
# Epoch 9/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8755 - loss: 0.3410 - val_accuracy: 0.8740 - val_loss: 0.3535
# Epoch 10/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8763 - loss: 0.3316 - val_accuracy: 0.8760 - val_loss: 0.3515
# Epoch 11/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8800 - loss: 0.3281 - val_accuracy: 0.8765 - val_loss: 0.3417
# Epoch 12/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8826 - loss: 0.3167 - val_accuracy: 0.8782 - val_loss: 0.3456
# Epoch 13/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8838 - loss: 0.3147 - val_accuracy: 0.8760 - val_loss: 0.3526
# Epoch 14/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8856 - loss: 0.3095 - val_accuracy: 0.8804 - val_loss: 0.3521
# Epoch 15/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8844 - loss: 0.3107 - val_accuracy: 0.8784 - val_loss: 0.3439
# Epoch 16/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8849 - loss: 0.3032 - val_accuracy: 0.8777 - val_loss: 0.3394
# Epoch 17/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8868 - loss: 0.3014 - val_accuracy: 0.8824 - val_loss: 0.3390
# Epoch 18/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8894 - loss: 0.2989 - val_accuracy: 0.8804 - val_loss: 0.3391
# Epoch 19/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8907 - loss: 0.2956 - val_accuracy: 0.8810 - val_loss: 0.3335
# Epoch 20/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8909 - loss: 0.2907 - val_accuracy: 0.8838 - val_loss: 0.3323
# Epoch 21/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8906 - loss: 0.2923 - val_accuracy: 0.8814 - val_loss: 0.3362
# Epoch 22/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8932 - loss: 0.2864 - val_accuracy: 0.8845 - val_loss: 0.3367
# Epoch 23/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8932 - loss: 0.2850 - val_accuracy: 0.8803 - val_loss: 0.3394
# Epoch 24/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8950 - loss: 0.2800 - val_accuracy: 0.8840 - val_loss: 0.3268
# Epoch 25/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8964 - loss: 0.2806 - val_accuracy: 0.8771 - val_loss: 0.3467
# Epoch 26/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8946 - loss: 0.2807 - val_accuracy: 0.8834 - val_loss: 0.3434
# Epoch 27/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8957 - loss: 0.2768 - val_accuracy: 0.8838 - val_loss: 0.3351

# %%
fig = plt.figure()
plt.plot(history.history['val_accuracy'], color='teal',label='Validation Accuracy')
plt.plot(history.history['accuracy'], color='orange', label='Train Accuracy')  
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['val_loss'], color = 'blue', label = 'Validation Loss')
plt.plot(history.history['loss'], color = 'orange', label='Train Accuracy')  
plt.legend(loc="upper left")
plt.show()

# %%
test_loss, test_acc_tf = model_tf.evaluate(test_images, test_labels, verbose=2) 
                                                                                
print('\nTest accuracy:', test_acc_tf)
# Out:
# 313/313 - 0s - 439us/step - accuracy: 0.8845 - loss: 0.3367
#
# Test accuracy: 0.8845000267028809

# %%
probability_model = tf.keras.Sequential([model_tf, 
                                         tf.keras.layers.Softmax()])

# %%
predictions_tf = probability_model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step

# %%
predictions_tf[0]
# Out:
# array([9.8951375e-11, 1.7837239e-10, 1.9702877e-09, 3.0981371e-09,
#        2.9781995e-09, 3.1570475e-05, 4.0211406e-10, 2.6849352e-03,
#        7.8729474e-11, 9.9728346e-01], dtype=float32)

# %%
np.argmax(predictions_tf[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):  
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    # Pastikan hanya memplot satu gambar
    img = img[i].squeeze()  # Menghilangkan dimensi ekstra jika ada
    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label[i]:
        color = 'blue'
    else:
        color = 'red'

    # Format label dengan nama kelas
    plt.xlabel(
        "{} {:2.0f}% ({})".format(
            class_names[predicted_label],  # Predicted class
            100 * np.max(predictions_array),  # Probability
            class_names[true_label[i]]  # True class
        ),
        color=color
    )

def plot_value_array(i, predictions_array, true_label): 
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label[i]].set_color('blue')

# %%
i=5
plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1)
plot_image(i, predictions_tf[i], test_labels, test_images)
plt.subplot(1, 2, 2)
plot_value_array(i, predictions_tf[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

num_rows = 5
num_cols = 4
num_images = num_rows * num_cols

correct_predictions = [np.argmax(predictions_tf[i]) == test_labels[i] for i in range(num_images)]
average_accuracy = np.mean(correct_predictions) * 100  

plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions_tf[i], test_labels, test_images)

    plt.subplot(num_rows, 2 * num_cols, 2 * i + 2)
    plot_value_array(i, predictions_tf[i], test_labels)

plt.suptitle(f'Akurasi Rata-rata: {average_accuracy:.2f}%')
plt.tight_layout()
plt.show()

# %%
img = test_images[1] 

print(img.shape)
# Out:
# (28, 28, 1)

# %%
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28, 1)

# %%
predictions_single = probability_model.predict(img) 
print(predictions_single)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [[1.52401059e-04 3.38504585e-10 9.92211103e-01 4.58279803e-10
#   5.66585967e-03 1.23402206e-14 1.97071116e-03 6.72497394e-21
#   4.55769936e-11 1.00262820e-16]]

# %%
plot_value_array(1, predictions_single[0], test_labels) 
_ = plt.xticks(range(10), class_names, rotation=45) 
plt.show()

# %%
np.argmax(predictions_single[0])
# Out:
# 2

# %%
df_test = pd.DataFrame({
    'Target': test_labels,  
    'Predicted': np.argmax(predictions_tf, axis=1),  
    'Proba_0': predictions_tf[:, 0],  
    'Proba_1': predictions_tf[:, 1]  
})

pixels = test_images.reshape(len(test_images), -1)

df_pixels = pd.DataFrame(pixels, columns=[f'pixel{i+1}' for i in range(28*28)])

df_test = pd.concat([df_test, df_pixels], axis=1)

# %%
df_plot = df_test.sample(16, random_state=84).copy()
fig, ax = plt.subplots(4, 4, figsize=(10, 10))

rata2_accuracy = (df_test['Target'] == df_test['Predicted']).mean() * 100

for i, axi in enumerate(ax.flat):
    p0 = df_plot['Proba_0'].values[i]
    p1 = df_plot['Proba_1'].values[i]

    predicted_class = df_plot['Predicted'].values[i]
    prediction_probability = max(p0, p1) * 100

    true_class = df_plot['Target'].values[i]

    pixels = df_plot[[f'pixel{j}' for j in range(1, 28*28 + 1)]].values[i].reshape(28, 28)
    axi.imshow(pixels, cmap='viridis')
    
    axi.set(xticks=[], yticks=[],
        xlabel=f"True: {true_class}\nPred: {predicted_class}\nProb: {prediction_probability:.2f}%")

    edge_color = 'green' if predicted_class == true_class else 'red'
    axi.spines[:].set_edgecolor(edge_color)
    axi.spines[:].set_linewidth(3)


fig.suptitle(f'Contoh gambar yang diklasifikasikan dari set pengujian\n'
             f'Batas hijau: klasifikasi benar\nAkurasi Keseluruhan: {rata2_accuracy:.2f}%')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Menggunakan Library Scikit-Learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore");
warnings.simplefilter("ignore");

# %%
from sklearn.datasets import fetch_openml
fashion_mnist = fetch_openml('Fashion-MNIST',version=1)

train_images = fashion_mnist.data[:60000] 
train_labels = fashion_mnist.target[:60000].astype(int)  
test_images = fashion_mnist.data[60000:]
test_labels = fashion_mnist.target[60000:].astype(int)

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, log_loss
from sklearn.model_selection import train_test_split
import numpy as np

train_images_split, val_images, train_labels_split, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=84
)

model_sklearn = MLPClassifier(hidden_layer_sizes=(128, 300),
                      activation='relu',
                      alpha=0.0001,
                      learning_rate_init=0.001,
                      early_stopping=True,
                      validation_fraction=0.2,
                      n_iter_no_change=10,
                      random_state=84,
                              
                      verbose=True)

model_sklearn.fit(train_images_split, train_labels_split)
training_loss = model_sklearn.loss_curve_
# Out:
# Iteration 1, loss = 0.63616622
# Validation score: 0.814479
# Iteration 2, loss = 0.42356234
# Validation score: 0.851042
# Iteration 3, loss = 0.37600745
# Validation score: 0.865938
# Iteration 4, loss = 0.34738260
# Validation score: 0.866354
# Iteration 5, loss = 0.32210153
# Validation score: 0.879167
# Iteration 6, loss = 0.30560784
# Validation score: 0.874896
# Iteration 7, loss = 0.28823862
# Validation score: 0.885521
# Iteration 8, loss = 0.27497981
# Validation score: 0.885208
# Iteration 9, loss = 0.26159936
# Validation score: 0.879479
# Iteration 10, loss = 0.25369497
# Validation score: 0.882812
# Iteration 11, loss = 0.24620253
# Validation score: 0.890625
# Iteration 12, loss = 0.23732933
# Validation score: 0.890104
# Iteration 13, loss = 0.23264901
# Validation score: 0.884687
# Iteration 14, loss = 0.22029706
# Validation score: 0.891563
# Iteration 15, loss = 0.21205330
# Validation score: 0.888229
# Iteration 16, loss = 0.20394500
# Validation score: 0.891458
# Iteration 17, loss = 0.19778550
# Validation score: 0.886354
# Iteration 18, loss = 0.18847529
# Validation score: 0.889479
# Iteration 19, loss = 0.18050062
# Validation score: 0.890625
# Iteration 20, loss = 0.17479060
# Validation score: 0.890833
# Iteration 21, loss = 0.17168302
# Validation score: 0.892292
# Iteration 22, loss = 0.16442571
# Validation score: 0.884271
# Iteration 23, loss = 0.15936802
# Validation score: 0.894792
# Iteration 24, loss = 0.15147703
# Validation score: 0.898125
# Iteration 25, loss = 0.14992317
# Validation score: 0.893750
# Iteration 26, loss = 0.14710433
# Validation score: 0.890625
# Iteration 27, loss = 0.13808760
# Validation score: 0.893021
# Iteration 28, loss = 0.13082485
# Validation score: 0.898229
# Iteration 29, loss = 0.12962552
# Validation score: 0.893125
# Iteration 30, loss = 0.12397132
# Validation score: 0.892292
# Iteration 31, loss = 0.11747479
# Validation score: 0.893750
# Iteration 32, loss = 0.11702249
# Validation score: 0.887188
# Iteration 33, loss = 0.11310071
# Validation score: 0.893958
# Iteration 34, loss = 0.11129402
# Validation score: 0.888646
# Iteration 35, loss = 0.10565198
# Validation score: 0.891354
# Iteration 36, loss = 0.09683896
# Validation score: 0.892083
# Iteration 37, loss = 0.09757537
# Validation score: 0.894167
# Iteration 38, loss = 0.09152429
# Validation score: 0.895938
# Iteration 39, loss = 0.09225845
# Validation score: 0.886771
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, val_scores = learning_curve(
    model_sklearn,train_images, train_labels, train_sizes=np.linspace(0.1, 1.0, 10), cv=5,
    scoring='neg_log_loss', random_state=84, n_jobs=-1)

train_loss_mean = -train_scores.mean(axis=1)
val_loss_mean = -val_scores.mean(axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_loss_mean, label='Training Loss')
plt.plot(train_sizes, val_loss_mean, label='Validation Loss')
plt.xlabel('Training Set Size')
plt.ylabel('Loss')
plt.title('Learning Curve (Training vs Validation Loss)')
plt.legend()
plt.show()
# Out:
# Iteration 1, loss = 1.42363149
# Validation score: 0.685417
# Iteration 2, loss = 0.70563982
# Validation score: 0.737500
# Iteration 1, loss = 1.08075139
# Validation score: 0.772917
# Iteration 3, loss = 0.59164627
# Validation score: 0.769792
# Iteration 1, loss = 0.92640716
# Validation score: 0.793056
# Iteration 4, loss = 0.55450780
# Validation score: 0.772917
# Iteration 2, loss = 0.60256248
# Validation score: 0.815104
# Iteration 5, loss = 0.49646803
# Iteration 1, loss = 0.82954550
# Validation score: 0.788542
# Validation score: 0.798958
# Iteration 6, loss = 0.46495609
# Validation score: 0.765625
# Iteration 3, loss = 0.51696461
# Validation score: 0.831250
# Iteration 1, loss = 0.78811394
# Iteration 7, loss = 0.43071229
# Iteration 2, loss = 0.53471638
# Validation score: 0.811458
# Validation score: 0.817014
# Validation score: 0.793125
# Iteration 8, loss = 0.39780766
# Validation score: 0.833333
# Iteration 1, loss = 0.74375360
# Iteration 4, loss = 0.47849355
# Validation score: 0.824479
# Validation score: 0.798611
# Iteration 9, loss = 0.38670917
# Validation score: 0.823958
# Iteration 2, loss = 0.50302632
# Iteration 1, loss = 0.69590260
# Validation score: 0.821354
# Iteration 10, loss = 0.36873042
# Validation score: 0.822917
# Iteration 3, loss = 0.45817445
# Iteration 5, loss = 0.42929453
# Validation score: 0.826736
# Validation score: 0.844792
# Validation score: 0.817708
# Iteration 11, loss = 0.36578321
# Validation score: 0.811458
# Iteration 12, loss = 0.35371902
# Validation score: 0.813542
# Iteration 6, loss = 0.41528142
# Validation score: 0.838021
# Iteration 2, loss = 0.48100969
# Validation score: 0.834792
# Iteration 1, loss = 0.66753173
# Iteration 13, loss = 0.33003244
# Iteration 4, loss = 0.41246517
# Validation score: 0.825000
# Validation score: 0.840278
# Iteration 3, loss = 0.44404597
# Iteration 14, loss = 0.30438016
# Validation score: 0.826042
# Iteration 7, loss = 0.38461160
# Validation score: 0.831380
# Validation score: 0.846094
# Validation score: 0.836458
# Iteration 2, loss = 0.46340925
# Iteration 15, loss = 0.30077646
# Validation score: 0.827083
# Validation score: 0.841840
# Iteration 16, loss = 0.29637132
# Validation score: 0.829167
# Iteration 8, loss = 0.37049767
# Iteration 5, loss = 0.39706837
# Validation score: 0.846354
# Validation score: 0.839583
# Iteration 17, loss = 0.27791187
# Validation score: 0.833333
# Iteration 2, loss = 0.45536542
# Iteration 18, loss = 0.26574014
# Validation score: 0.841667
# Iteration 3, loss = 0.43224835
# Iteration 4, loss = 0.39688293
# Validation score: 0.849583
# Iteration 9, loss = 0.34289623
# Validation score: 0.851042
# Validation score: 0.855729
# Iteration 19, loss = 0.25749269
# Validation score: 0.818750
# Iteration 6, loss = 0.36890289
# Iteration 20, loss = 0.26036788
# Validation score: 0.832292
# Validation score: 0.843056
# Iteration 10, loss = 0.34658018
# Validation score: 0.850521
# Iteration 21, loss = 0.27404413
# Validation score: 0.835417
# Validation score: 0.833780
# Iteration 22, loss = 0.24729301
# Validation score: 0.815625
# Iteration 11, loss = 0.33136443
# Validation score: 0.846875
# Iteration 23, loss = 0.23930482
# Validation score: 0.826042
# Iteration 7, loss = 0.34799420
# Validation score: 0.843056
# Iteration 5, loss = 0.37194718
# Iteration 24, loss = 0.21125150
# Validation score: 0.829167
# Validation score: 0.846354
# Iteration 12, loss = 0.31097045
# Validation score: 0.859375
# Iteration 25, loss = 0.21540632
# Validation score: 0.840625
# Iteration 26, loss = 0.19863598
# Validation score: 0.843750
# Iteration 8, loss = 0.33407970
# Validation score: 0.842708
# Iteration 13, loss = 0.29478665
# Validation score: 0.842708
# Iteration 27, loss = 0.19738251
# Validation score: 0.842708
# Iteration 3, loss = 0.40768475
# Iteration 28, loss = 0.19672661
# Validation score: 0.815625
# Validation score: 0.849132
# Iteration 4, loss = 0.38628219
# Iteration 14, loss = 0.29257598
# Iteration 29, loss = 0.17493592
# Validation score: 0.832292
# Validation score: 0.848437
# Iteration 6, loss = 0.36654805
# Validation score: 0.850417
# Iteration 30, loss = 0.16540422
# Validation score: 0.835417
# Iteration 9, loss = 0.31794522
# Validation score: 0.836806
# Iteration 31, loss = 0.16497025
# Iteration 15, loss = 0.27997799
# Validation score: 0.841667
# Validation score: 0.855208
# Iteration 32, loss = 0.15576252
# Validation score: 0.833333
# Iteration 33, loss = 0.14079560
# Validation score: 0.833333
# Iteration 16, loss = 0.26313727
# Iteration 34, loss = 0.14844998
# Validation score: 0.831250
# Iteration 35, loss = 0.14745450
# Validation score: 0.819792
# Iteration 36, loss = 0.14725379
# Validation score: 0.866667
# Validation score: 0.844792
# Validation score: 0.862500
# Iteration 10, loss = 0.29736733
# Iteration 37, loss = 0.11842806
# Validation score: 0.838542
# Validation score: 0.859722
# Iteration 38, loss = 0.11470600
# Validation score: 0.834375
# Iteration 17, loss = 0.24730871
# Iteration 39, loss = 0.10928022
# Validation score: 0.803125
# Validation score: 0.848437
# Iteration 11, loss = 0.28839927
# Iteration 40, loss = 0.12818853
# Validation score: 0.835417
# Validation score: 0.850000
# Iteration 18, loss = 0.24557557
# Iteration 41, loss = 0.10187814
# Validation score: 0.864062
# Validation score: 0.826042
# Iteration 42, loss = 0.13639487
# Validation score: 0.827083
# Iteration 19, loss = 0.23079701
# Validation score: 0.855729
# Iteration 43, loss = 0.12749113
# Iteration 12, loss = 0.27817863
# Validation score: 0.838542
# Validation score: 0.862500
# Iteration 44, loss = 0.11743314
# Validation score: 0.826042
# Iteration 20, loss = 0.22342153
# Iteration 45, loss = 0.09239091
# Validation score: 0.838542
# Validation score: 0.857812
# Iteration 46, loss = 0.09198385
# Validation score: 0.829167
# Iteration 13, loss = 0.26754339
# Validation score: 0.855556
# Iteration 47, loss = 0.09631696
# Validation score: 0.835417
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 21, loss = 0.20877432
# Validation score: 0.856771
# Iteration 22, loss = 0.20534621
# Validation score: 0.861458
# Iteration 14, loss = 0.24940187
# Validation score: 0.862153
# Iteration 2, loss = 0.44289656
# Iteration 23, loss = 0.19346907
# Validation score: 0.859375
# Iteration 15, loss = 0.25163352
# Validation score: 0.857639
# Iteration 24, loss = 0.18925171
# Validation score: 0.855208
# Validation score: 0.834766
# Iteration 7, loss = 0.34253662
# Iteration 25, loss = 0.17812771
# Validation score: 0.859375
# Iteration 16, loss = 0.25648641
# Validation score: 0.843056
# Validation score: 0.852344
# Iteration 5, loss = 0.36091051
# Iteration 26, loss = 0.17332147
# Validation score: 0.858333
# Validation score: 0.858125
# Iteration 17, loss = 0.23191590
# Validation score: 0.861458
# Iteration 27, loss = 0.17652507
# Validation score: 0.857292
# Iteration 4, loss = 0.37253183
# Iteration 28, loss = 0.15796847
# Validation score: 0.855208
# Iteration 3, loss = 0.39734230
# Iteration 18, loss = 0.22146833
# Validation score: 0.859375
# Iteration 29, loss = 0.15650980
# Validation score: 0.847768
# Validation score: 0.862674
# Validation score: 0.861458
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 8, loss = 0.32927545
# Validation score: 0.856771
# Iteration 19, loss = 0.20440396
# Validation score: 0.868750
# Iteration 6, loss = 0.34121874
# Iteration 20, loss = 0.21484261
# Validation score: 0.860069
# Iteration 9, loss = 0.30418545
# Validation score: 0.857292
# Validation score: 0.850521
# Iteration 21, loss = 0.20359798
# Validation score: 0.855903
# Iteration 10, loss = 0.29663658
# Validation score: 0.869010
# Iteration 3, loss = 0.39164492
# Iteration 5, loss = 0.35295493
# Iteration 22, loss = 0.19214310
# Validation score: 0.858681
# Iteration 7, loss = 0.32647812
# Validation score: 0.863958
# Iteration 4, loss = 0.36975506
# Validation score: 0.854557
# Validation score: 0.851736
# Iteration 23, loss = 0.19378310
# Validation score: 0.863194
# Iteration 11, loss = 0.27743572
# Validation score: 0.859635
# Validation score: 0.856845
# Iteration 24, loss = 0.17771295
# Validation score: 0.859722
# Iteration 12, loss = 0.27650493
# Validation score: 0.859375
# Iteration 25, loss = 0.16832927
# Iteration 8, loss = 0.30629964
# Validation score: 0.863542
# Validation score: 0.864167
# Iteration 26, loss = 0.17053932
# Validation score: 0.866319
# Iteration 6, loss = 0.33411502
# Iteration 13, loss = 0.25487150
# Validation score: 0.855208
# Validation score: 0.875000
# Iteration 27, loss = 0.15305236
# Validation score: 0.868056
# Iteration 5, loss = 0.34078359
# Iteration 14, loss = 0.24819901
# Validation score: 0.875521
# Iteration 9, loss = 0.28976375
# Iteration 28, loss = 0.14372717
# Validation score: 0.864931
# Validation score: 0.847321
# Validation score: 0.857292
# Iteration 4, loss = 0.35641133
# Iteration 29, loss = 0.14149465
# Validation score: 0.866146
# Iteration 15, loss = 0.23877876
# Validation score: 0.862847
# Validation score: 0.876042
# Iteration 7, loss = 0.31129416
# Validation score: 0.868056
# Iteration 30, loss = 0.14618767
# Validation score: 0.864583
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 10, loss = 0.28532824
# Iteration 16, loss = 0.23545593
# Validation score: 0.863333
# Validation score: 0.871354
# Iteration 6, loss = 0.32494424
# Iteration 17, loss = 0.22189143
# Validation score: 0.875521
# Iteration 8, loss = 0.30120444
# Iteration 11, loss = 0.26236956
# Validation score: 0.854911
# Validation score: 0.869167
# Validation score: 0.873611
# Iteration 5, loss = 0.33740263
# Iteration 18, loss = 0.20618880
# Validation score: 0.869792
# Validation score: 0.867318
# Iteration 12, loss = 0.26039880
# Validation score: 0.871042
# Iteration 9, loss = 0.28695869
# Validation score: 0.878819
# Iteration 19, loss = 0.20768943
# Validation score: 0.873177
# Iteration 7, loss = 0.30568556
# Validation score: 0.860417
# Iteration 13, loss = 0.24167689
# Validation score: 0.868750
# Iteration 20, loss = 0.20143184
# Validation score: 0.864844
# Iteration 10, loss = 0.27361937
# Validation score: 0.875174
# Iteration 6, loss = 0.31492901
# Iteration 21, loss = 0.19233098
# Validation score: 0.869792
# Iteration 14, loss = 0.23548061
# Validation score: 0.874740
# Iteration 8, loss = 0.29412468
# Validation score: 0.872500
# Validation score: 0.869643
# Iteration 22, loss = 0.17684072
# Iteration 11, loss = 0.26200958
# Validation score: 0.866146
# Validation score: 0.877778
# Iteration 15, loss = 0.22913917
# Validation score: 0.870208
# Iteration 23, loss = 0.17491463
# Iteration 7, loss = 0.29763402
# Validation score: 0.870573
# Iteration 9, loss = 0.27711443
# Validation score: 0.874870
# Validation score: 0.864583
# Iteration 12, loss = 0.25582716
# Iteration 16, loss = 0.21954089
# Validation score: 0.886285
# Iteration 1, loss = 1.36272897
# Validation score: 0.866458
# Validation score: 0.701042
# Iteration 24, loss = 0.17693007
# Iteration 2, loss = 0.70585936
# Validation score: 0.798958
# Validation score: 0.865625
# Iteration 3, loss = 0.58293760
# Validation score: 0.810417
# Iteration 4, loss = 0.52980200
# Validation score: 0.826042
# Iteration 5, loss = 0.46491464
# Validation score: 0.827083
# Iteration 17, loss = 0.21795320
# Iteration 25, loss = 0.16879968
# Iteration 10, loss = 0.26456209
# Iteration 6, loss = 0.43363098
# Validation score: 0.783333
# Validation score: 0.870052
# Validation score: 0.862292
# Iteration 13, loss = 0.24563816
# Validation score: 0.869196
# Iteration 8, loss = 0.28706400
# Iteration 7, loss = 0.44185027
# Validation score: 0.819792
# Validation score: 0.881076
# Validation score: 0.877604
# Iteration 8, loss = 0.39891122
# Validation score: 0.844792
# Iteration 9, loss = 0.36309531
# Validation score: 0.840625
# Iteration 10, loss = 0.34884082
# Validation score: 0.844792
# Iteration 26, loss = 0.15676401
# Validation score: 0.863542
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 11, loss = 0.33278754
# Validation score: 0.857292
# Iteration 18, loss = 0.20154367
# Iteration 12, loss = 0.30975555
# Validation score: 0.853125
# Validation score: 0.870625
# Iteration 13, loss = 0.30507594
# Validation score: 0.854167
# Iteration 14, loss = 0.23252265
# Iteration 14, loss = 0.30949660
# Validation score: 0.855208
# Validation score: 0.885243
# Iteration 15, loss = 0.28266138
# Validation score: 0.851042
# Iteration 11, loss = 0.25704899
# Iteration 16, loss = 0.26460927
# Validation score: 0.841667
# Validation score: 0.870238
# Iteration 17, loss = 0.25700051
# Validation score: 0.836458
# Iteration 9, loss = 0.27044184
# Iteration 19, loss = 0.19831232
# Iteration 18, loss = 0.26637672
# Validation score: 0.845833
# Validation score: 0.868333
# Validation score: 0.883203
# Iteration 19, loss = 0.24621256
# Validation score: 0.855208
# Iteration 20, loss = 0.24286764
# Validation score: 0.833333
# Iteration 1, loss = 0.65610723
# Iteration 21, loss = 0.24791974
# Validation score: 0.861458
# Iteration 15, loss = 0.22671708
# Iteration 22, loss = 0.21063602
# Validation score: 0.836458
# Validation score: 0.889062
# Validation score: 0.832060
# Iteration 23, loss = 0.22203187
# Validation score: 0.855208
# Iteration 1, loss = 0.63108054
# Iteration 20, loss = 0.19947859
# Iteration 24, loss = 0.18609475
# Iteration 1, loss = 1.05717799
# Validation score: 0.858333
# Validation score: 0.776563
# Validation score: 0.815208
# Validation score: 0.871042
# Iteration 12, loss = 0.24639359
# Iteration 25, loss = 0.18405054
# Validation score: 0.842708
# Validation score: 0.868452
# Iteration 26, loss = 0.20528464
# Validation score: 0.863542
# Iteration 2, loss = 0.58438488
# Validation score: 0.802083
# Iteration 27, loss = 0.17963386
# Validation score: 0.854167
# Iteration 10, loss = 0.25975985
# Iteration 3, loss = 0.51396540
# Iteration 28, loss = 0.16789295
# Validation score: 0.829688
# Validation score: 0.853125
# Iteration 16, loss = 0.21815542
# Validation score: 0.885807
# Iteration 29, loss = 0.16137106
# Validation score: 0.852083
# Iteration 21, loss = 0.18835336
# Validation score: 0.881076
# Validation score: 0.871458
# Iteration 30, loss = 0.16151607
# Validation score: 0.861458
# Iteration 4, loss = 0.46690986
# Validation score: 0.817187
# Iteration 31, loss = 0.14052256
# Validation score: 0.850000
# Iteration 32, loss = 0.13704274
# Validation score: 0.858333
# Iteration 5, loss = 0.43259435
# Validation score: 0.838021
# Iteration 2, loss = 0.42623287
# Iteration 13, loss = 0.23762435
# Iteration 33, loss = 0.13534977
# Validation score: 0.826042
# Validation score: 0.867113
# Iteration 6, loss = 0.39402942
# Validation score: 0.825694
# Validation score: 0.833333
# Iteration 34, loss = 0.15773446
# Validation score: 0.844792
# Iteration 2, loss = 0.41968105
# Iteration 22, loss = 0.17479460
# Validation score: 0.868958
# Iteration 35, loss = 0.14960598
# Validation score: 0.847917
# Validation score: 0.853542
# Iteration 17, loss = 0.20974246
# Iteration 7, loss = 0.36733728
# Validation score: 0.846354
# Iteration 36, loss = 0.13781821
# Validation score: 0.852083
# Validation score: 0.868750
# Iteration 37, loss = 0.10074627
# Validation score: 0.841667
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 11, loss = 0.25275188
# Iteration 8, loss = 0.35782275
# Validation score: 0.845833
# Validation score: 0.874089
# Iteration 9, loss = 0.33456421
# Iteration 23, loss = 0.17016039
# Validation score: 0.845313
# Iteration 14, loss = 0.23252305
# Validation score: 0.867083
# Validation score: 0.880952
# Iteration 10, loss = 0.32304944
# Validation score: 0.855208
# Iteration 18, loss = 0.20340444
# Iteration 11, loss = 0.30030375
# Validation score: 0.852083
# Validation score: 0.888021
# Iteration 3, loss = 0.38609717
# Iteration 12, loss = 0.28803307
# Validation score: 0.841667
# Iteration 24, loss = 0.17070819
# Validation score: 0.864583
# Iteration 1, loss = 0.92306639
# Validation score: 0.774306
# Validation score: 0.858449
# Iteration 13, loss = 0.30775655
# Validation score: 0.855729
# Iteration 3, loss = 0.37465001
# Iteration 12, loss = 0.24413650
# Iteration 14, loss = 0.26872355
# Validation score: 0.855729
# Iteration 2, loss = 0.52001135
# Validation score: 0.865729
# Iteration 19, loss = 0.20203872
# Validation score: 0.829167
# Iteration 15, loss = 0.22145877
# Validation score: 0.885938
# Iteration 15, loss = 0.25208332
# Validation score: 0.867708
# Validation score: 0.860938
# Validation score: 0.874219
# Iteration 25, loss = 0.16254714
# Validation score: 0.867292
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 16, loss = 0.23888393
# Iteration 3, loss = 0.45634124
# Validation score: 0.848958
# Validation score: 0.819444
# Iteration 17, loss = 0.24598367
# Validation score: 0.853125
# Iteration 4, loss = 0.42792597
# Validation score: 0.808333
# Iteration 20, loss = 0.19304763
# Iteration 18, loss = 0.22870133
# Validation score: 0.854167
# Validation score: 0.878125
# Iteration 16, loss = 0.21177270
# Iteration 5, loss = 0.38843694
# Iteration 19, loss = 0.20598220
# Validation score: 0.866815
# Validation score: 0.850521
# Iteration 4, loss = 0.35155478
# Validation score: 0.843056
# Validation score: 0.863889
# Iteration 20, loss = 0.20630338
# Validation score: 0.838021
# Iteration 6, loss = 0.36277648
# Iteration 13, loss = 0.23430214
# Validation score: 0.844792
# Iteration 21, loss = 0.20769811
# Validation score: 0.845313
# Validation score: 0.878255
# Iteration 21, loss = 0.18252689
# Iteration 4, loss = 0.34396269
# Validation score: 0.886979
# Validation score: 0.872500
# Iteration 22, loss = 0.20150819
# Validation score: 0.850521
# Iteration 7, loss = 0.34016605
# Validation score: 0.854514
# Iteration 17, loss = 0.20917054
# Validation score: 0.876042
# Iteration 23, loss = 0.18464164
# Validation score: 0.851562
# Iteration 8, loss = 0.32431200
# Validation score: 0.827778
# Iteration 24, loss = 0.18182510
# Validation score: 0.854167
# Iteration 5, loss = 0.32609220
# Iteration 22, loss = 0.17649760
# Iteration 14, loss = 0.23151225
# Validation score: 0.870255
# Iteration 25, loss = 0.16891791
# Validation score: 0.885417
# Validation score: 0.851562
# Iteration 9, loss = 0.31006650
# Validation score: 0.852778
# Validation score: 0.885547
# Iteration 26, loss = 0.16643689
# Validation score: 0.857812
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 18, loss = 0.20087971
# Iteration 1, loss = 0.82613269
# Validation score: 0.873958
# Iteration 10, loss = 0.28427467
# Validation score: 0.825000
# Validation score: 0.850347
# Iteration 5, loss = 0.32292681
# Validation score: 0.877604
# Iteration 23, loss = 0.16737462
# Validation score: 0.879687
# Iteration 11, loss = 0.27872832
# Validation score: 0.851736
# Iteration 2, loss = 0.49973902
# Validation score: 0.834375
# Iteration 15, loss = 0.22397011
# Iteration 6, loss = 0.30569603
# Iteration 12, loss = 0.25753417
# Validation score: 0.855208
# Validation score: 0.874306
# Iteration 19, loss = 0.19562087
# Validation score: 0.891536
# Validation score: 0.877530
# Iteration 3, loss = 0.43437763
# Validation score: 0.850521
# Iteration 24, loss = 0.16777736
# Iteration 13, loss = 0.25750550
# Validation score: 0.857986
# Validation score: 0.888542
# Iteration 1, loss = 0.77373700
# Validation score: 0.818958
# Iteration 14, loss = 0.23963148
# Iteration 4, loss = 0.38927762
# Validation score: 0.853819
# Validation score: 0.855469
# Iteration 6, loss = 0.30404810
# Iteration 15, loss = 0.23510871
# Validation score: 0.846528
# Iteration 2, loss = 0.47628615
# Validation score: 0.829167
# Iteration 16, loss = 0.20754509
# Iteration 5, loss = 0.36121107
# Validation score: 0.880000
# Iteration 20, loss = 0.18220057
# Validation score: 0.856771
# Iteration 25, loss = 0.16032678
# Iteration 16, loss = 0.22559360
# Validation score: 0.879613
# Validation score: 0.889844
# Validation score: 0.853125
# Validation score: 0.873090
# Iteration 17, loss = 0.20379406
# Validation score: 0.854514
# Iteration 6, loss = 0.33988547
# Validation score: 0.861979
# Iteration 7, loss = 0.29525921
# Iteration 18, loss = 0.20753998
# Validation score: 0.845139
# Iteration 3, loss = 0.42693414
# Iteration 7, loss = 0.32637436
# Validation score: 0.857292
# Validation score: 0.859115
# Iteration 19, loss = 0.21433375
# Validation score: 0.857292
# Validation score: 0.870602
# Iteration 20, loss = 0.18714860
# Iteration 8, loss = 0.30384431
# Validation score: 0.853125
# Iteration 26, loss = 0.17131648
# Validation score: 0.867969
# Validation score: 0.880903
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 4, loss = 0.38287304
# Validation score: 0.863958
# Iteration 21, loss = 0.17774102
# Validation score: 0.855903
# Iteration 21, loss = 0.18245729
# Validation score: 0.870982
# Iteration 9, loss = 0.28747987
# Validation score: 0.865365
# Iteration 17, loss = 0.19836067
# Iteration 22, loss = 0.17266860
# Validation score: 0.845833
# Validation score: 0.888021
# Iteration 5, loss = 0.35718690
# Iteration 7, loss = 0.28749660
# Validation score: 0.869583
# Validation score: 0.883542
# Iteration 10, loss = 0.27227187
# Iteration 23, loss = 0.18109371
# Validation score: 0.871094
# Validation score: 0.857639
# Iteration 8, loss = 0.28154154
# Validation score: 0.882407
# Iteration 22, loss = 0.17867683
# Iteration 24, loss = 0.16644443
# Validation score: 0.854167
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 11, loss = 0.25768619
# Validation score: 0.876935
# Iteration 6, loss = 0.33296759
# Validation score: 0.864062
# Validation score: 0.866458
# Iteration 18, loss = 0.19227568
# Validation score: 0.889323
# Iteration 12, loss = 0.25433002
# Validation score: 0.857812
# Iteration 7, loss = 0.31036754
# Validation score: 0.874583
# Iteration 8, loss = 0.27509563
# Iteration 23, loss = 0.16899272
# Validation score: 0.879167
# Iteration 9, loss = 0.26574726
# Iteration 13, loss = 0.24416525
# Validation score: 0.876190
# Validation score: 0.872656
# Validation score: 0.881366
# Iteration 8, loss = 0.29773023
# Validation score: 0.868750
# Iteration 19, loss = 0.18728229
# Iteration 14, loss = 0.23100671
# Validation score: 0.873698
# Validation score: 0.889193
# Iteration 24, loss = 0.15733148
# Iteration 15, loss = 0.24518005
# Validation score: 0.864137
# Validation score: 0.871354
# Iteration 9, loss = 0.28127108
# Validation score: 0.872500
# Iteration 9, loss = 0.26698461
# Iteration 10, loss = 0.25329290
# Iteration 16, loss = 0.22387064
# Validation score: 0.869010
# Validation score: 0.882396
# Validation score: 0.879398
# Iteration 10, loss = 0.27057122
# Iteration 20, loss = 0.18301510
# Validation score: 0.872292
# Validation score: 0.890755
# Iteration 17, loss = 0.20640638
# Validation score: 0.872396
# Iteration 25, loss = 0.16018797
# Validation score: 0.874702
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.72390110
# Iteration 18, loss = 0.19664163
# Iteration 11, loss = 0.25674313
# Iteration 1, loss = 0.69029663
# Validation score: 0.874479
# Validation score: 0.875417
# Validation score: 0.810417
# Validation score: 0.829464
# Iteration 11, loss = 0.24577922
# Iteration 19, loss = 0.19644063
# Iteration 10, loss = 0.25252253
# Validation score: 0.876563
# Iteration 21, loss = 0.17449976
# Validation score: 0.882060
# Validation score: 0.878542
# Validation score: 0.889583
# Iteration 12, loss = 0.25492500
# Validation score: 0.878542
# Iteration 2, loss = 0.45573594
# Iteration 20, loss = 0.18525510
# Validation score: 0.849132
# Validation score: 0.869792
# Iteration 2, loss = 0.44381958
# Validation score: 0.847173
# Iteration 21, loss = 0.19329327
# Validation score: 0.872917
# Iteration 13, loss = 0.23684668
# Validation score: 0.878750
# Iteration 3, loss = 0.39853329
# Iteration 22, loss = 0.16922318
# Validation score: 0.841840
# Validation score: 0.871094
# Iteration 12, loss = 0.23635703
# Iteration 22, loss = 0.17290357
# Validation score: 0.881366
# Validation score: 0.888281
# Iteration 14, loss = 0.23344067
# Iteration 23, loss = 0.16023519
# Iteration 3, loss = 0.39391329
# Validation score: 0.872656
# Validation score: 0.882292
# Validation score: 0.860714
# Iteration 11, loss = 0.24676431
# Validation score: 0.884479
# Iteration 4, loss = 0.36115842
# Validation score: 0.855208
# Iteration 24, loss = 0.15769715
# Validation score: 0.870573
# Iteration 15, loss = 0.21684120
# Validation score: 0.880208
# Iteration 23, loss = 0.16245640
# Iteration 25, loss = 0.14585846
# Validation score: 0.878125
# Validation score: 0.886979
# Iteration 4, loss = 0.36427365
# Iteration 13, loss = 0.22866595
# Iteration 5, loss = 0.35572576
# Validation score: 0.859077
# Iteration 16, loss = 0.21084713
# Validation score: 0.851736
# Iteration 26, loss = 0.14261329
# Validation score: 0.879427
# Validation score: 0.880208
# Validation score: 0.878356
# Iteration 27, loss = 0.14571268
# Validation score: 0.875521
# Iteration 17, loss = 0.20946828
# Validation score: 0.876042
# Iteration 28, loss = 0.13498257
# Validation score: 0.870313
# Iteration 6, loss = 0.32298450
# Iteration 18, loss = 0.20086153
# Validation score: 0.880382
# Validation score: 0.881458
# Iteration 12, loss = 0.23784851
# Iteration 29, loss = 0.13767005
# Validation score: 0.885000
# Validation score: 0.881510
# Iteration 5, loss = 0.33578586
# Validation score: 0.863690
# Iteration 24, loss = 0.16179963
# Iteration 19, loss = 0.19440695
# Validation score: 0.889844
# Validation score: 0.877917
# Iteration 30, loss = 0.12563090
# Iteration 7, loss = 0.30736997
# Validation score: 0.877083
# Validation score: 0.873611
# Iteration 14, loss = 0.21928577
# Validation score: 0.885532
# Iteration 31, loss = 0.12732442
# Iteration 20, loss = 0.18603922
# Validation score: 0.872396
# Validation score: 0.876667
# Iteration 6, loss = 0.31770460
# Validation score: 0.863839
# Iteration 32, loss = 0.12110584
# Validation score: 0.879948
# Iteration 8, loss = 0.30317428
# Iteration 33, loss = 0.11040766
# Validation score: 0.871615
# Iteration 21, loss = 0.18970446
# Validation score: 0.874479
# Iteration 34, loss = 0.10159555
# Validation score: 0.873958
# Validation score: 0.876042
# Iteration 1, loss = 0.67315698
# Iteration 25, loss = 0.15018527
# Iteration 35, loss = 0.10128736
# Validation score: 0.873177
# Validation score: 0.846094
# Iteration 13, loss = 0.22954024
# Iteration 22, loss = 0.17094618
# Validation score: 0.882292
# Iteration 36, loss = 0.10658960
# Validation score: 0.868750
# Validation score: 0.887630
# Iteration 23, loss = 0.16460281
# Validation score: 0.885000
# Iteration 37, loss = 0.09160583
# Validation score: 0.878906
# Validation score: 0.888125
# Iteration 9, loss = 0.27718342
# Validation score: 0.881771
# Iteration 38, loss = 0.08426960
# Validation score: 0.877083
# Iteration 24, loss = 0.15487228
# Validation score: 0.878958
# Iteration 7, loss = 0.29685881
# Iteration 39, loss = 0.08380194
# Iteration 15, loss = 0.21127242
# Validation score: 0.870833
# Validation score: 0.868899
# Iteration 2, loss = 0.43840685
# Iteration 25, loss = 0.15951461
# Validation score: 0.890278
# Validation score: 0.878750
# Validation score: 0.840625
# Iteration 40, loss = 0.09023734
# Validation score: 0.871354
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 10, loss = 0.26646658
# Validation score: 0.873611
# Iteration 26, loss = 0.14367358
# Validation score: 0.886979
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 26, loss = 0.15673299
# Validation score: 0.881250
# Iteration 8, loss = 0.28884721
# Iteration 14, loss = 0.21902809
# Validation score: 0.877083
# Validation score: 0.891667
# Iteration 3, loss = 0.38633756
# Iteration 11, loss = 0.25295839
# Validation score: 0.861589
# Validation score: 0.882118
# Iteration 16, loss = 0.20096334
# Validation score: 0.888079
# Iteration 27, loss = 0.14101558
# Validation score: 0.877292
# Iteration 9, loss = 0.27072728
# Iteration 12, loss = 0.25205227
# Validation score: 0.872768
# Validation score: 0.883507
# Iteration 28, loss = 0.13826635
# Validation score: 0.876875
# Iteration 4, loss = 0.35983161
# Validation score: 0.872786
# Iteration 15, loss = 0.21442673
# Iteration 17, loss = 0.19602632
# Iteration 29, loss = 0.13035570
# Iteration 13, loss = 0.23672673
# Validation score: 0.874583
# Validation score: 0.889352
# Validation score: 0.886771
# Validation score: 0.884896
# Iteration 10, loss = 0.26278455
# Validation score: 0.879018
# Iteration 30, loss = 0.12810532
# Validation score: 0.880833
# Iteration 5, loss = 0.33192180
# Iteration 14, loss = 0.22722899
# Validation score: 0.872526
# Validation score: 0.884201
# Iteration 11, loss = 0.24819470
# Iteration 31, loss = 0.12449561
# Validation score: 0.878869
# Iteration 18, loss = 0.19225862
# Validation score: 0.877708
# Validation score: 0.890856
# Iteration 16, loss = 0.21234960
# Validation score: 0.883542
# Iteration 15, loss = 0.22011172
# Validation score: 0.886632
# Iteration 32, loss = 0.12734843
# Validation score: 0.880000
# Iteration 6, loss = 0.31353317
# Validation score: 0.862891
# Iteration 12, loss = 0.24392294
# Validation score: 0.868452
# Iteration 33, loss = 0.11437537
# Iteration 16, loss = 0.21258886
# Validation score: 0.878125
# Validation score: 0.874306
# Iteration 19, loss = 0.18184904
# Validation score: 0.883796
# Iteration 17, loss = 0.19849155
# Iteration 34, loss = 0.11081321
# Iteration 7, loss = 0.29566289
# Validation score: 0.876667
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 13, loss = 0.23481581
# Validation score: 0.880313
# Validation score: 0.868359
# Validation score: 0.871280
# Iteration 17, loss = 0.21303759
# Validation score: 0.867882
# Iteration 1, loss = 0.64875283
# Iteration 20, loss = 0.18099342
# Iteration 14, loss = 0.22172634
# Iteration 18, loss = 0.20142431
# Validation score: 0.885185
# Validation score: 0.884077
# Validation score: 0.881944
# Iteration 8, loss = 0.28720963
# Validation score: 0.883594
# Validation score: 0.835648
# Iteration 19, loss = 0.19494014
# Iteration 18, loss = 0.19357907
# Validation score: 0.888021
# Iteration 15, loss = 0.21385872
# Validation score: 0.885119
# Validation score: 0.887396
# Iteration 20, loss = 0.18487682
# Iteration 9, loss = 0.27132102
# Validation score: 0.887674
# Iteration 16, loss = 0.20301566
# Validation score: 0.874256
# Validation score: 0.874870
# Iteration 21, loss = 0.18250014
# Validation score: 0.885938
# Iteration 17, loss = 0.20423835
# Iteration 21, loss = 0.17086979
# Validation score: 0.884673
# Iteration 22, loss = 0.17109281
# Validation score: 0.887500
# Validation score: 0.882523
# Iteration 18, loss = 0.19876184
# Validation score: 0.882738
# Iteration 23, loss = 0.16256745
# Validation score: 0.885938
# Iteration 24, loss = 0.16655154
# Validation score: 0.888194
# Iteration 19, loss = 0.19280886
# Validation score: 0.879762
# Iteration 1, loss = 0.62369322
# Iteration 10, loss = 0.25628961
# Iteration 25, loss = 0.15280408
# Iteration 2, loss = 0.42408595
# Validation score: 0.885807
# Validation score: 0.878993
# Iteration 20, loss = 0.17830284
# Validation score: 0.831354
# Iteration 19, loss = 0.18775481
# Validation score: 0.882292
# Validation score: 0.828935
# Iteration 22, loss = 0.16693290
# Iteration 26, loss = 0.15429449
# Validation score: 0.886343
# Validation score: 0.888368
# Validation score: 0.886354
# Iteration 21, loss = 0.17589558
# Validation score: 0.882143
# Iteration 27, loss = 0.14972494
# Validation score: 0.884549
# Iteration 11, loss = 0.25414224
# Validation score: 0.882422
# Iteration 22, loss = 0.17257001
# Iteration 28, loss = 0.14364610
# Validation score: 0.890278
# Validation score: 0.887798
# Iteration 23, loss = 0.16195584
# Validation score: 0.877778
# Iteration 29, loss = 0.13005652
# Validation score: 0.883681
# Iteration 23, loss = 0.16477703
# Iteration 3, loss = 0.38026617
# Validation score: 0.881101
# Iteration 12, loss = 0.23764957
# Validation score: 0.878776
# Iteration 30, loss = 0.12667533
# Validation score: 0.878646
# Validation score: 0.861921
# Iteration 2, loss = 0.41680566
# Iteration 20, loss = 0.18233393
# Iteration 24, loss = 0.16339902
# Iteration 1, loss = 1.36272897
# Validation score: 0.701042
# Validation score: 0.882887
# Iteration 2, loss = 0.70585936
# Validation score: 0.798958
# Iteration 3, loss = 0.58293760
# Validation score: 0.810417
# Iteration 4, loss = 0.52980200
# Validation score: 0.826042
# Iteration 5, loss = 0.46491464
# Validation score: 0.827083
# Iteration 31, loss = 0.12649605
# Iteration 6, loss = 0.43363098
# Validation score: 0.783333
# Iteration 7, loss = 0.44185027
# Validation score: 0.819792
# Iteration 8, loss = 0.39891122
# Validation score: 0.844792
# Validation score: 0.883681
# Iteration 9, loss = 0.36309531
# Validation score: 0.840625
# Iteration 10, loss = 0.34884082
# Validation score: 0.844792
# Validation score: 0.886979
# Iteration 11, loss = 0.33278754
# Validation score: 0.857292
# Validation score: 0.853958
# Iteration 12, loss = 0.30975555
# Validation score: 0.853125
# Iteration 13, loss = 0.30507594
# Validation score: 0.854167
# Iteration 14, loss = 0.30949660
# Validation score: 0.855208
# Iteration 15, loss = 0.28266138
# Validation score: 0.851042
# Iteration 13, loss = 0.23372582
# Iteration 16, loss = 0.26460927
# Validation score: 0.841667
# Iteration 24, loss = 0.15765772
# Iteration 17, loss = 0.25700051
# Validation score: 0.836458
# Validation score: 0.879557
# Iteration 18, loss = 0.26637672
# Validation score: 0.845833
# Iteration 19, loss = 0.24621256
# Validation score: 0.855208
# Validation score: 0.889815
# Iteration 20, loss = 0.24286764
# Validation score: 0.833333
# Iteration 21, loss = 0.24791974
# Validation score: 0.861458
# Iteration 22, loss = 0.21063602
# Validation score: 0.836458
# Iteration 23, loss = 0.22203187
# Validation score: 0.855208
# Iteration 24, loss = 0.18609475
# Validation score: 0.858333
# Iteration 25, loss = 0.18405054
# Validation score: 0.842708
# Iteration 25, loss = 0.14871479
# Iteration 26, loss = 0.20528464
# Validation score: 0.863542
# Iteration 27, loss = 0.17963386
# Validation score: 0.854167
# Iteration 28, loss = 0.16789295
# Validation score: 0.853125
# Iteration 29, loss = 0.16137106
# Validation score: 0.852083
# Iteration 32, loss = 0.11718561
# Validation score: 0.880506
# Iteration 30, loss = 0.16151607
# Validation score: 0.861458
# Iteration 31, loss = 0.14052256
# Validation score: 0.850000
# Iteration 32, loss = 0.13704274
# Validation score: 0.858333
# Validation score: 0.888715
# Iteration 33, loss = 0.13534977
# Validation score: 0.826042
# Iteration 34, loss = 0.15773446
# Validation score: 0.844792
# Iteration 35, loss = 0.14960598
# Validation score: 0.847917
# Iteration 36, loss = 0.13781821
# Validation score: 0.852083
# Iteration 37, loss = 0.10074627
# Validation score: 0.841667
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 4, loss = 0.34243457
# Validation score: 0.871412
# Iteration 33, loss = 0.11491289
# Iteration 26, loss = 0.14754896
# Validation score: 0.887500
# Iteration 14, loss = 0.22557519
# Validation score: 0.887946
# Validation score: 0.887891
# Iteration 25, loss = 0.14806091
# Validation score: 0.883333
# Iteration 21, loss = 0.17162392
# Iteration 34, loss = 0.11911140
# Validation score: 0.880208
# Iteration 3, loss = 0.37454896
# Validation score: 0.887917
# Iteration 27, loss = 0.14035848
# Validation score: 0.865625
# Validation score: 0.880060
# Iteration 5, loss = 0.32799698
# Iteration 15, loss = 0.21699493
# Iteration 35, loss = 0.11259467
# Validation score: 0.871181
# Validation score: 0.882292
# Validation score: 0.881944
# Iteration 26, loss = 0.13995891
# Validation score: 0.889468
# Iteration 28, loss = 0.13673388
# Iteration 22, loss = 0.17001134
# Iteration 36, loss = 0.11182483
# Validation score: 0.888690
# Validation score: 0.879687
# Validation score: 0.890625
# Iteration 4, loss = 0.33770253
# Iteration 16, loss = 0.20539120
# Iteration 6, loss = 0.30719101
# Validation score: 0.874583
# Validation score: 0.892318
# Validation score: 0.875347
# Iteration 37, loss = 0.11516547
# Iteration 29, loss = 0.12662929
# Validation score: 0.884028
# Iteration 27, loss = 0.13693390
# Validation score: 0.884226
# Validation score: 0.887731
# Iteration 23, loss = 0.16115798
# Iteration 17, loss = 0.20596167
# Validation score: 0.891458
# Validation score: 0.877734
# Iteration 7, loss = 0.29059595
# Iteration 5, loss = 0.32016073
# Iteration 38, loss = 0.10126543
# Validation score: 0.878356
# Validation score: 0.878958
# Validation score: 0.887500
# Iteration 30, loss = 0.12624820
# Validation score: 0.887500
# Iteration 28, loss = 0.13603673
# Validation score: 0.889120
# Iteration 18, loss = 0.19871295
# Iteration 39, loss = 0.10065171
# Validation score: 0.887847
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Validation score: 0.888281
# Iteration 24, loss = 0.15263942
# Validation score: 0.888646
# Iteration 8, loss = 0.28217878
# Iteration 31, loss = 0.12352631
# Validation score: 0.885714
# Validation score: 0.879398
# Iteration 6, loss = 0.30117992
# Iteration 1, loss = 1.05717799
# Validation score: 0.776563
# Validation score: 0.881563
# Iteration 29, loss = 0.13050119
# Iteration 2, loss = 0.58438488
# Validation score: 0.802083
# Validation score: 0.889931
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 19, loss = 0.18530004
# Iteration 3, loss = 0.51396540
# Validation score: 0.879297
# Validation score: 0.829688
# Iteration 32, loss = 0.11491980
# Iteration 4, loss = 0.46690986
# Validation score: 0.817187
# Validation score: 0.884524
# Iteration 5, loss = 0.43259435
# Validation score: 0.838021
# Iteration 25, loss = 0.15555870
# Iteration 9, loss = 0.26553115
# Validation score: 0.894479
# Iteration 6, loss = 0.39402942
# Validation score: 0.884838
# Validation score: 0.833333
# Iteration 7, loss = 0.28352707
# Iteration 7, loss = 0.36733728
# Validation score: 0.846354
# Iteration 20, loss = 0.18108368
# Validation score: 0.879896
# Validation score: 0.886458
# Iteration 33, loss = 0.11379144
# Iteration 8, loss = 0.35782275
# Validation score: 0.845833
# Validation score: 0.879911
# Iteration 9, loss = 0.33456421
# Validation score: 0.845313
# Iteration 10, loss = 0.32304944
# Validation score: 0.855208
# Iteration 11, loss = 0.30030375
# Iteration 10, loss = 0.25585702
# Validation score: 0.852083
# Iteration 26, loss = 0.14618445
# Validation score: 0.883565
# Iteration 34, loss = 0.10166997
# Iteration 12, loss = 0.28803307
# Validation score: 0.841667
# Iteration 21, loss = 0.17803329
# Validation score: 0.887917
# Validation score: 0.883185
# Validation score: 0.893359
# Iteration 13, loss = 0.30775655
# Validation score: 0.855729
# Iteration 14, loss = 0.26872355
# Validation score: 0.855729
# Iteration 8, loss = 0.27497666
# Iteration 15, loss = 0.25208332
# Validation score: 0.860938
# Validation score: 0.881146
# Iteration 16, loss = 0.23888393
# Validation score: 0.848958
# Iteration 17, loss = 0.24598367
# Validation score: 0.853125
# Iteration 35, loss = 0.10788985
# Iteration 18, loss = 0.22870133
# Validation score: 0.854167
# Iteration 1, loss = 0.91580993
# Validation score: 0.883185
# Validation score: 0.783333
# Iteration 19, loss = 0.20598220
# Validation score: 0.850521
# Iteration 11, loss = 0.24387201
# Iteration 22, loss = 0.16405330
# Validation score: 0.882639
# Iteration 20, loss = 0.20630338
# Validation score: 0.888411
# Validation score: 0.838021
# Iteration 2, loss = 0.51333192
# Validation score: 0.818403
# Iteration 27, loss = 0.14430080
# Iteration 21, loss = 0.20769811
# Validation score: 0.845313
# Validation score: 0.891563
# Iteration 22, loss = 0.20150819
# Iteration 3, loss = 0.45286264
# Validation score: 0.850521
# Validation score: 0.816319
# Iteration 23, loss = 0.18464164
# Validation score: 0.851562
# Iteration 36, loss = 0.10294664
# Iteration 4, loss = 0.41031104
# Validation score: 0.820833
# Iteration 9, loss = 0.26307939
# Iteration 24, loss = 0.18182510
# Validation score: 0.854167
# Validation score: 0.882292
# Iteration 1, loss = 0.82750823
# Validation score: 0.817448
# Validation score: 0.885729
# Iteration 25, loss = 0.16891791
# Validation score: 0.851562
# Iteration 5, loss = 0.37984091
# Validation score: 0.842361
# Iteration 26, loss = 0.16643689
# Iteration 23, loss = 0.16362613
# Validation score: 0.857812
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 12, loss = 0.23713262
# Validation score: 0.889193
# Iteration 6, loss = 0.35864170
# Iteration 2, loss = 0.49062250
# Validation score: 0.852083
# Validation score: 0.823958
# Validation score: 0.890046
# Iteration 7, loss = 0.34232111
# Validation score: 0.844792
# Iteration 37, loss = 0.10143390
# Iteration 3, loss = 0.44867667
# Validation score: 0.875000
# Validation score: 0.839063
# Iteration 28, loss = 0.14185397
# Iteration 8, loss = 0.33416606
# Validation score: 0.832292
# Validation score: 0.890104
# Iteration 10, loss = 0.25605971
# Iteration 24, loss = 0.15840173
# Iteration 4, loss = 0.39573974
# Iteration 9, loss = 0.30920790
# Validation score: 0.846615
# Validation score: 0.846528
# Validation score: 0.887891
# Validation score: 0.879687
# Iteration 13, loss = 0.22941101
# Iteration 10, loss = 0.28909771
# Iteration 38, loss = 0.09121468
# Validation score: 0.848958
# Iteration 5, loss = 0.37204885
# Validation score: 0.878125
# Validation score: 0.853385
# Validation score: 0.884524
# Iteration 11, loss = 0.27771035
# Validation score: 0.848264
# Iteration 6, loss = 0.34259922
# Validation score: 0.851823
# Iteration 12, loss = 0.26820529
# Validation score: 0.853125
# Iteration 1, loss = 0.77615516
# Validation score: 0.807083
# Iteration 7, loss = 0.33210555
# Iteration 13, loss = 0.25766876
# Validation score: 0.866927
# Validation score: 0.857639
# Iteration 25, loss = 0.15043395
# Iteration 14, loss = 0.24749396
# Validation score: 0.850000
# Validation score: 0.881380
# Iteration 29, loss = 0.13199195
# Iteration 8, loss = 0.30825082
# Validation score: 0.867448
# Iteration 2, loss = 0.47201412
# Validation score: 0.895417
# Validation score: 0.839375
# Iteration 15, loss = 0.23367277
# Validation score: 0.830556
# Iteration 39, loss = 0.08205818
# Iteration 9, loss = 0.29649124
# Validation score: 0.865365
# Validation score: 0.879167
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 16, loss = 0.23259215
# Validation score: 0.855556
# Iteration 14, loss = 0.21849777
# Iteration 3, loss = 0.42031860
# Iteration 17, loss = 0.21089788
# Validation score: 0.855903
# Validation score: 0.850625
# Iteration 10, loss = 0.28193589
# Validation score: 0.865365
# Iteration 11, loss = 0.23878528
# Validation score: 0.887963
# Iteration 18, loss = 0.21350104
# Validation score: 0.843750
# Iteration 11, loss = 0.27346877
# Validation score: 0.880938
# Validation score: 0.866146
# Iteration 4, loss = 0.38310942
# Iteration 26, loss = 0.14518091
# Validation score: 0.850417
# Iteration 19, loss = 0.20787655
# Validation score: 0.853125
# Validation score: 0.893620
# Iteration 12, loss = 0.25310575
# Iteration 20, loss = 0.19761627
# Validation score: 0.860417
# Validation score: 0.864323
# Iteration 5, loss = 0.36314374
# Validation score: 0.856875
# Iteration 21, loss = 0.18178561
# Validation score: 0.863542
# Iteration 13, loss = 0.25011998
# Validation score: 0.864583
# Iteration 22, loss = 0.17773925
# Validation score: 0.857639
# Iteration 6, loss = 0.33327739
# Iteration 23, loss = 0.17847542
# Validation score: 0.857292
# Iteration 14, loss = 0.24011782
# Validation score: 0.868958
# Validation score: 0.866406
# Iteration 30, loss = 0.12628776
# Iteration 24, loss = 0.16811245
# Validation score: 0.887708
# Validation score: 0.851736
# Iteration 15, loss = 0.21251451
# Iteration 15, loss = 0.23887152
# Validation score: 0.871094
# Iteration 25, loss = 0.16817554
# Validation score: 0.860417
# Iteration 7, loss = 0.32342511
# Validation score: 0.864583
# Iteration 27, loss = 0.13816417
# Validation score: 0.888773
# Iteration 26, loss = 0.15211369
# Validation score: 0.859028
# Iteration 16, loss = 0.22158415
# Validation score: 0.889583
# Validation score: 0.868490
# Iteration 12, loss = 0.23663373
# Iteration 27, loss = 0.14814133
# Iteration 8, loss = 0.29867095
# Validation score: 0.854167
# Validation score: 0.867292
# Validation score: 0.883750
# Iteration 17, loss = 0.21269827
# Validation score: 0.867188
# Iteration 28, loss = 0.14514001
# Validation score: 0.853125
# Iteration 9, loss = 0.28822352
# Iteration 29, loss = 0.13051328
# Iteration 18, loss = 0.20751409
# Validation score: 0.862847
# Validation score: 0.867083
# Validation score: 0.867969
# Iteration 28, loss = 0.13732080
# Iteration 31, loss = 0.12648546
# Validation score: 0.882943
# Iteration 30, loss = 0.12334269
# Iteration 16, loss = 0.20349060
# Validation score: 0.862847
# Validation score: 0.887813
# Validation score: 0.888426
# Iteration 19, loss = 0.19584573
# Validation score: 0.870833
# Iteration 10, loss = 0.27410192
# Iteration 31, loss = 0.12004219
# Validation score: 0.869167
# Validation score: 0.860764
# Iteration 13, loss = 0.22308611
# Iteration 20, loss = 0.19483484
# Iteration 32, loss = 0.11263483
# Validation score: 0.856944
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Validation score: 0.863542
# Validation score: 0.892500
# Iteration 11, loss = 0.26376909
# Validation score: 0.865625
# Iteration 29, loss = 0.13833564
# Iteration 21, loss = 0.18899512
# Validation score: 0.873958
# Validation score: 0.888021
# Iteration 12, loss = 0.25226627
# Iteration 17, loss = 0.19363915
# Validation score: 0.854792
# Iteration 22, loss = 0.17788473
# Iteration 32, loss = 0.12133421
# Validation score: 0.868490
# Validation score: 0.889931
# Validation score: 0.889583
# Iteration 23, loss = 0.17037413
# Validation score: 0.863542
# Iteration 13, loss = 0.24895692
# Validation score: 0.875000
# Iteration 14, loss = 0.21397574
# Iteration 30, loss = 0.12728906
# Iteration 24, loss = 0.16365295
# Validation score: 0.859896
# Iteration 14, loss = 0.23980146
# Validation score: 0.888542
# Validation score: 0.875625
# Iteration 25, loss = 0.15884087
# Validation score: 0.873177
# Validation score: 0.886667
# Iteration 1, loss = 0.72066533
# Iteration 18, loss = 0.19100683
# Validation score: 0.805382
# Iteration 15, loss = 0.22907260
# Validation score: 0.893981
# Validation score: 0.871667
# Iteration 26, loss = 0.15571514
# Validation score: 0.875000
# Iteration 33, loss = 0.11254881
# Iteration 31, loss = 0.12342095
# Validation score: 0.891979
# Iteration 27, loss = 0.16593945
# Iteration 16, loss = 0.21318494
# Iteration 2, loss = 0.46310315
# Validation score: 0.891276
# Validation score: 0.867969
# Validation score: 0.878125
# Validation score: 0.839931
# Iteration 15, loss = 0.21017635
# Iteration 28, loss = 0.14538529
# Validation score: 0.870573
# Iteration 19, loss = 0.18491766
# Iteration 17, loss = 0.21049297
# Validation score: 0.884167
# Validation score: 0.871875
# Validation score: 0.882176
# Iteration 3, loss = 0.40479976
# Validation score: 0.835764
# Iteration 29, loss = 0.14122164
# Iteration 32, loss = 0.11618380
# Validation score: 0.877865
# Validation score: 0.883594
# Iteration 34, loss = 0.10843235
# Iteration 18, loss = 0.20589922
# Validation score: 0.871875
# Validation score: 0.889792
# Iteration 30, loss = 0.12488860
# Iteration 1, loss = 0.68746749
# Validation score: 0.872656
# Iteration 4, loss = 0.38246736
# Validation score: 0.809821
# Validation score: 0.848958
# Iteration 20, loss = 0.17774800
# Iteration 16, loss = 0.20445099
# Iteration 19, loss = 0.19164144
# Validation score: 0.888773
# Validation score: 0.882917
# Iteration 31, loss = 0.11984426
# Iteration 33, loss = 0.12190426
# Validation score: 0.888437
# Validation score: 0.871615
# Validation score: 0.888802
# Iteration 5, loss = 0.34985606
# Iteration 2, loss = 0.45343830
# Validation score: 0.856771
# Iteration 32, loss = 0.12100368
# Validation score: 0.828720
# Iteration 20, loss = 0.18927841
# Validation score: 0.878125
# Iteration 35, loss = 0.10559201
# Validation score: 0.880208
# Validation score: 0.895417
# Iteration 21, loss = 0.17071577
# Iteration 33, loss = 0.11567741
# Iteration 34, loss = 0.10895812
# Validation score: 0.872396
# Validation score: 0.881829
# Iteration 21, loss = 0.18118823
# Iteration 6, loss = 0.33133284
# Validation score: 0.887891
# Iteration 17, loss = 0.19389614
# Validation score: 0.881458
# Validation score: 0.854514
# Iteration 3, loss = 0.39649868
# Validation score: 0.885208
# Iteration 34, loss = 0.10815894
# Validation score: 0.849256
# Validation score: 0.870833
# Iteration 22, loss = 0.17049466
# Validation score: 0.884583
# Iteration 7, loss = 0.30942575
# Iteration 36, loss = 0.10408320
# Validation score: 0.869792
# Iteration 35, loss = 0.10667596
# Validation score: 0.875000
# Iteration 35, loss = 0.10992079
# Validation score: 0.890208
# Iteration 22, loss = 0.16406820
# Validation score: 0.884635
# Validation score: 0.888889
# Iteration 4, loss = 0.36609922
# Validation score: 0.856696
# Iteration 36, loss = 0.10790095
# Iteration 23, loss = 0.16351032
# Validation score: 0.876667
# Validation score: 0.873177
# Iteration 18, loss = 0.19295055
# Iteration 8, loss = 0.29327428
# Validation score: 0.868403
# Validation score: 0.887396
# Iteration 37, loss = 0.10933143
# Validation score: 0.871875
# Iteration 24, loss = 0.15937653
# Iteration 36, loss = 0.10906606
# Validation score: 0.882292
# Iteration 5, loss = 0.33581558
# Validation score: 0.886979
# Iteration 23, loss = 0.15787622
# Iteration 37, loss = 0.09852488
# Validation score: 0.866369
# Iteration 9, loss = 0.27609719
# Validation score: 0.893750
# Iteration 38, loss = 0.10071842
# Validation score: 0.863889
# Validation score: 0.892500
# Validation score: 0.869531
# Iteration 25, loss = 0.15114297
# ...
# Iteration 10, loss = 0.25961244
# Iteration 20, loss = 0.19012370
# Validation score: 0.894687
# Validation score: 0.870139
# Validation score: 0.873958
# Validation score: 0.877827
# Iteration 8, loss = 0.29120107
# Iteration 34, loss = 0.10815894
# Iteration 31, loss = 0.12317833
# Validation score: 0.870833
# Validation score: 0.872917
# Validation score: 0.889352
# Iteration 21, loss = 0.18417720
# Iteration 35, loss = 0.10667596
# Validation score: 0.884375
# Validation score: 0.875000
# Iteration 2, loss = 0.42391659
# Iteration 13, loss = 0.23707439
# Validation score: 0.854167
# Validation score: 0.869618
# Iteration 11, loss = 0.25401356
# Validation score: 0.875446
# Iteration 36, loss = 0.10790095
# Validation score: 0.873177
# Iteration 27, loss = 0.13469916
# Iteration 22, loss = 0.17297572
# Iteration 9, loss = 0.27027401
# Validation score: 0.876875
# Validation score: 0.883073
# Validation score: 0.893333
# Iteration 32, loss = 0.12006404
# Validation score: 0.886921
# Iteration 14, loss = 0.22735335
# Validation score: 0.864062
# Iteration 37, loss = 0.10933143
# Validation score: 0.871875
# Iteration 12, loss = 0.24197878
# Iteration 3, loss = 0.37757869
# Iteration 23, loss = 0.16690712
# Validation score: 0.883333
# Validation score: 0.872292
# Validation score: 0.862037
# Iteration 38, loss = 0.10071842
# Validation score: 0.869531
# Iteration 10, loss = 0.26139911
# Iteration 15, loss = 0.22138216
# Validation score: 0.873264
# Validation score: 0.881641
# Iteration 24, loss = 0.16365299
# Iteration 28, loss = 0.13341733
# Validation score: 0.883125
# Iteration 39, loss = 0.09082271
# Iteration 33, loss = 0.11922844
# Validation score: 0.867969
# Validation score: 0.893854
# Validation score: 0.888426
# Iteration 13, loss = 0.23485613
# Validation score: 0.868006
# Iteration 4, loss = 0.34857099
# Iteration 16, loss = 0.21150996
# Iteration 40, loss = 0.08961247
# Validation score: 0.875231
# Iteration 25, loss = 0.15439307
# Validation score: 0.872135
# Validation score: 0.877083
# Validation score: 0.881458
# Iteration 11, loss = 0.25239502
# Validation score: 0.880208
# Iteration 41, loss = 0.09263575
# Iteration 14, loss = 0.22595497
# Validation score: 0.879427
# Validation score: 0.881101
# Iteration 34, loss = 0.11085449
# Iteration 26, loss = 0.14911869
# Validation score: 0.875208
# Validation score: 0.885995
# Iteration 17, loss = 0.20098929
# Iteration 29, loss = 0.13332673
# Validation score: 0.873437
# Validation score: 0.892292
# Iteration 42, loss = 0.08964634
# Validation score: 0.877344
# Iteration 5, loss = 0.32733237
# Validation score: 0.876968
# Iteration 12, loss = 0.24230445
# Iteration 27, loss = 0.14819912
# Validation score: 0.886458
# Validation score: 0.877865
# Iteration 15, loss = 0.21850689
# Iteration 43, loss = 0.08611797
# Iteration 18, loss = 0.19749021
# Validation score: 0.868750
# Validation score: 0.888690
# Validation score: 0.871007
# Iteration 35, loss = 0.10791132
# Iteration 28, loss = 0.13908259
# Validation score: 0.882176
# Validation score: 0.881042
# Iteration 44, loss = 0.07703026
# Validation score: 0.872656
# Iteration 30, loss = 0.12642589
# Iteration 13, loss = 0.23503265
# Iteration 19, loss = 0.19000490
# Validation score: 0.893229
# Validation score: 0.871528
# Validation score: 0.882552
# Iteration 6, loss = 0.30263876
# Iteration 16, loss = 0.21010140
# Validation score: 0.875231
# Validation score: 0.882292
# Iteration 45, loss = 0.07775952
# Validation score: 0.872135
# Iteration 29, loss = 0.13795525
# Validation score: 0.883542
# Iteration 20, loss = 0.19246057
# Iteration 46, loss = 0.07704625
# Iteration 36, loss = 0.10935687
# Validation score: 0.880729
# Validation score: 0.864844
# Validation score: 0.890509
# Iteration 30, loss = 0.13456365
# Iteration 14, loss = 0.22617747
# Validation score: 0.880417
# Iteration 17, loss = 0.20798556
# Validation score: 0.890755
# Validation score: 0.879167
# Iteration 7, loss = 0.29383812
# Iteration 31, loss = 0.12446716
# Iteration 47, loss = 0.07361780
# Validation score: 0.874740
# Validation score: 0.873958
# Validation score: 0.890625
# Iteration 21, loss = 0.18435707
# Iteration 31, loss = 0.12376028
# Validation score: 0.876736
# Validation score: 0.886667
# Iteration 48, loss = 0.05683151
# Validation score: 0.873437
# Iteration 37, loss = 0.10026394
# Iteration 18, loss = 0.19777228
# Validation score: 0.887269
# Validation score: 0.884970
# Iteration 15, loss = 0.21916155
# Validation score: 0.886198
# Iteration 49, loss = 0.05657480
# Iteration 32, loss = 0.11539298
# Validation score: 0.861979
# Validation score: 0.876042
# Iteration 22, loss = 0.17823935
# Validation score: 0.878993
# Iteration 8, loss = 0.28095026
# Validation score: 0.874653
# Iteration 32, loss = 0.11698340
# Validation score: 0.891458
# Iteration 50, loss = 0.05755039
# Validation score: 0.868750
# Iteration 33, loss = 0.12430760
# Iteration 19, loss = 0.19387608
# Validation score: 0.881458
# Validation score: 0.883482
# Iteration 23, loss = 0.16959952
# Iteration 16, loss = 0.21070687
# Validation score: 0.871875
# Validation score: 0.890625
# Iteration 38, loss = 0.10101815
# Iteration 51, loss = 0.04593563
# Validation score: 0.887269
# Validation score: 0.871094
# Iteration 34, loss = 0.12110780
# Validation score: 0.879583
# Iteration 9, loss = 0.26716748
# Validation score: 0.883681
# Iteration 20, loss = 0.18615406
# Iteration 52, loss = 0.05194660
# Validation score: 0.870313
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Validation score: 0.886905
# Iteration 24, loss = 0.16608650
# Iteration 33, loss = 0.11749462
# Validation score: 0.868229
# Validation score: 0.885729
# Iteration 35, loss = 0.11277260
# Iteration 17, loss = 0.20199337
# Validation score: 0.883750
# Validation score: 0.889714
# Iteration 39, loss = 0.09818820
# Validation score: 0.886458
# Iteration 25, loss = 0.16014496
# Iteration 21, loss = 0.17784416
# Validation score: 0.867535
# Iteration 36, loss = 0.10850424
# Validation score: 0.884970
# Iteration 10, loss = 0.25395579
# Validation score: 0.883333
# Validation score: 0.884259
# Iteration 18, loss = 0.20427190
# Iteration 34, loss = 0.10911823
# Iteration 26, loss = 0.15169959
# Validation score: 0.894661
# Iteration 37, loss = 0.10834709
# Validation score: 0.879167
# Validation score: 0.893542
# Validation score: 0.882292
# Iteration 22, loss = 0.16933609
# Iteration 40, loss = 0.09631350
# Validation score: 0.885119
# Validation score: 0.885648
# Iteration 38, loss = 0.09406926
# Validation score: 0.881875
# Iteration 27, loss = 0.14430794
# Validation score: 0.881424
# Iteration 11, loss = 0.24384772
# Iteration 1, loss = 0.61740170
# Iteration 19, loss = 0.19476002
# Validation score: 0.881944
# Validation score: 0.840521
# Validation score: 0.889193
# Iteration 23, loss = 0.16576468
# Iteration 39, loss = 0.09622364
# Validation score: 0.879167
# Validation score: 0.887798
# Iteration 28, loss = 0.13679463
# Validation score: 0.873264
# Iteration 35, loss = 0.10747687
# Validation score: 0.884167
# Iteration 41, loss = 0.08809683
# Iteration 40, loss = 0.09020279
# Validation score: 0.877500
# Validation score: 0.889815
# Iteration 24, loss = 0.16107702
# Iteration 20, loss = 0.18072724
# Iteration 29, loss = 0.13473162
# Validation score: 0.886458
# Iteration 12, loss = 0.24099559
# Validation score: 0.894271
# Validation score: 0.878299
# Validation score: 0.871296
# Iteration 2, loss = 0.41374354
# Iteration 41, loss = 0.08667052
# Validation score: 0.880417
# Validation score: 0.855000
# Iteration 36, loss = 0.09739134
# Iteration 42, loss = 0.07721479
# Iteration 30, loss = 0.13003868
# Validation score: 0.894560
# Validation score: 0.892292
# Iteration 25, loss = 0.15532544
# Validation score: 0.868056
# Iteration 42, loss = 0.08181670
# Validation score: 0.876458
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 21, loss = 0.17733290
# Validation score: 0.891667
# Validation score: 0.894401
# Iteration 13, loss = 0.23158567
# Validation score: 0.888542
# Iteration 3, loss = 0.36508190
# Iteration 31, loss = 0.12605730
# Validation score: 0.859583
# Validation score: 0.878819
# Iteration 26, loss = 0.14887559
# Validation score: 0.892560
# Iteration 43, loss = 0.07686380
# Iteration 22, loss = 0.17032765
# Iteration 37, loss = 0.09435536
# Validation score: 0.891435
# Validation score: 0.892188
# Validation score: 0.890938
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 32, loss = 0.12744353
# Validation score: 0.875521
# Iteration 14, loss = 0.22178008
# Validation score: 0.882523
# Iteration 27, loss = 0.14750017
# Iteration 4, loss = 0.34101801
# Validation score: 0.884821
# Validation score: 0.872188
# Iteration 23, loss = 0.16925349
# Iteration 33, loss = 0.11888011
# Validation score: 0.888021
# Iteration 44, loss = 0.08127221
# Validation score: 0.880556
# Validation score: 0.884375
# Iteration 15, loss = 0.21611197
# Iteration 28, loss = 0.14265396
# Validation score: 0.892708
# Validation score: 0.888657
# Iteration 34, loss = 0.11160489
# Validation score: 0.881944
# Iteration 24, loss = 0.15866072
# Validation score: 0.883724
# Iteration 5, loss = 0.31466369
# Validation score: 0.866563
# Iteration 45, loss = 0.08009135
# Iteration 29, loss = 0.13281428
# Validation score: 0.887153
# Validation score: 0.888690
# Iteration 35, loss = 0.11077299
# Validation score: 0.878993
# Iteration 16, loss = 0.20837604
# Validation score: 0.884491
# Iteration 25, loss = 0.16076405
# Validation score: 0.888542
# Iteration 30, loss = 0.13047951
# Iteration 36, loss = 0.10637436
# Validation score: 0.888690
# Validation score: 0.882812
# Iteration 6, loss = 0.29730400
# Iteration 46, loss = 0.07102937
# Validation score: 0.882292
# Validation score: 0.889236
# Iteration 17, loss = 0.20034544
# Validation score: 0.891667
# Iteration 37, loss = 0.10929643
# Validation score: 0.874132
# Iteration 31, loss = 0.12922555
# Iteration 26, loss = 0.14722838
# Validation score: 0.887798
# Validation score: 0.891536
# Iteration 47, loss = 0.07115771
# Iteration 7, loss = 0.28239994
# Validation score: 0.888310
# Iteration 38, loss = 0.10498138
# Validation score: 0.875625
# Validation score: 0.872743
# Iteration 32, loss = 0.12609379
# Validation score: 0.880655
# Iteration 18, loss = 0.19564338
# Validation score: 0.891782
# Iteration 27, loss = 0.14287895
# Validation score: 0.894271
# Iteration 39, loss = 0.10561790
# Validation score: 0.874132
# Iteration 48, loss = 0.07057767
# Iteration 33, loss = 0.11792906
# Validation score: 0.886921
# Validation score: 0.890774
# Iteration 8, loss = 0.26753069
# Validation score: 0.886875
# Iteration 19, loss = 0.18554567
# Iteration 28, loss = 0.14502276
# Validation score: 0.886921
# Iteration 40, loss = 0.08938440
# Validation score: 0.892448
# Validation score: 0.881771
# Iteration 34, loss = 0.11019131
# Validation score: 0.890625
# Iteration 49, loss = 0.06639119
# Iteration 41, loss = 0.08200755
# Validation score: 0.883565
# Validation score: 0.872569
# Iteration 29, loss = 0.13311610
# Iteration 9, loss = 0.25710615
# Validation score: 0.888542
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 20, loss = 0.18022573
# Validation score: 0.886563
# Validation score: 0.888889
# Iteration 35, loss = 0.11037394
# Validation score: 0.887351
# Iteration 42, loss = 0.08238367
# Validation score: 0.870660
# Iteration 50, loss = 0.07109061
# Validation score: 0.881250
# Iteration 21, loss = 0.17928366
# Iteration 43, loss = 0.08405264
# Iteration 36, loss = 0.10129778
# Iteration 10, loss = 0.24978618
# Validation score: 0.874826
# Validation score: 0.890162
# Validation score: 0.889435
# Validation score: 0.880729
# Iteration 44, loss = 0.07441554
# Iteration 51, loss = 0.06987825
# Validation score: 0.878819
# Iteration 37, loss = 0.09646888
# Validation score: 0.887384
# Validation score: 0.888542
# Iteration 22, loss = 0.16889978
# Validation score: 0.888310
# Iteration 11, loss = 0.24185065
# Validation score: 0.889792
# Iteration 45, loss = 0.07151977
# Validation score: 0.879340
# Iteration 38, loss = 0.09447653
# Validation score: 0.877679
# Iteration 52, loss = 0.06558904
# Validation score: 0.881597
# Iteration 46, loss = 0.08203552
# Iteration 23, loss = 0.16370172
# Validation score: 0.877083
# Validation score: 0.884028
# Iteration 39, loss = 0.09814845
# Iteration 12, loss = 0.22917867
# Validation score: 0.885417
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Validation score: 0.884062
# Iteration 53, loss = 0.06077909
# Iteration 47, loss = 0.06883156
# Validation score: 0.872743
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Validation score: 0.890162
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 24, loss = 0.15578469
# Validation score: 0.879630
# Iteration 13, loss = 0.22103509
# Validation score: 0.890938
# Iteration 25, loss = 0.15496544
# Validation score: 0.894907
# Iteration 14, loss = 0.21309739
# Validation score: 0.889479
# Iteration 26, loss = 0.14137193
# Validation score: 0.883333
# Iteration 15, loss = 0.20360762
# Validation score: 0.889896
# Iteration 27, loss = 0.15412282
# Validation score: 0.889005
# Iteration 16, loss = 0.20331992
# Validation score: 0.885938
# Iteration 28, loss = 0.14219840
# Validation score: 0.889931
# Iteration 17, loss = 0.19782118
# Validation score: 0.891875
# Iteration 29, loss = 0.13040937
# Validation score: 0.891551
# Iteration 18, loss = 0.18099857
# Iteration 30, loss = 0.12632362
# Validation score: 0.893333
# Validation score: 0.890394
# Iteration 31, loss = 0.12583747
# Iteration 19, loss = 0.17673563
# Validation score: 0.889236
# Validation score: 0.892500
# Iteration 32, loss = 0.11941130
# Validation score: 0.891204
# Iteration 20, loss = 0.17691445
# Validation score: 0.889271
# Iteration 33, loss = 0.12165314
# Validation score: 0.893403
# Iteration 21, loss = 0.17266940
# Validation score: 0.892604
# Iteration 34, loss = 0.11022535
# Validation score: 0.890856
# Iteration 22, loss = 0.16185958
# Validation score: 0.883646
# Iteration 35, loss = 0.10341893
# Validation score: 0.897917
# Iteration 23, loss = 0.15528665
# Validation score: 0.890104
# Iteration 36, loss = 0.10417573
# Validation score: 0.891435
# Iteration 24, loss = 0.15106946
# Validation score: 0.891250
# Iteration 37, loss = 0.09944120
# Validation score: 0.889583
# Iteration 25, loss = 0.14803700
# Validation score: 0.886354
# Iteration 38, loss = 0.10158543
# Validation score: 0.890625
# Iteration 26, loss = 0.14244622
# Validation score: 0.891771
# Iteration 39, loss = 0.09904473
# Validation score: 0.892593
# Iteration 27, loss = 0.13066096
# Iteration 40, loss = 0.08754755
# Validation score: 0.887083
# Validation score: 0.892130
# Iteration 41, loss = 0.09284834
# Iteration 28, loss = 0.13541252
# Validation score: 0.884144
# Validation score: 0.894896
# Iteration 42, loss = 0.08431823
# Validation score: 0.892014
# Iteration 29, loss = 0.12403835
# Validation score: 0.890104
# Iteration 43, loss = 0.07483086
# Validation score: 0.892824
# Iteration 30, loss = 0.12719752
# Validation score: 0.888958
# Iteration 44, loss = 0.08059340
# Validation score: 0.894097
# Iteration 31, loss = 0.12117102
# Validation score: 0.892500
# Iteration 45, loss = 0.07833247
# Validation score: 0.885648
# Iteration 32, loss = 0.11266338
# Validation score: 0.892292
# Iteration 46, loss = 0.07574531
# Validation score: 0.895486
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 33, loss = 0.11442082
# Validation score: 0.889479
# Iteration 34, loss = 0.10939863
# Validation score: 0.892396
# Iteration 35, loss = 0.10382908
# Validation score: 0.894062
# Iteration 36, loss = 0.09369917
# Validation score: 0.893125
# Iteration 37, loss = 0.09486991
# Validation score: 0.896667
# Iteration 38, loss = 0.09073237
# Validation score: 0.893854
# Iteration 39, loss = 0.09479560
# Validation score: 0.893958
# Iteration 40, loss = 0.08063870
# Validation score: 0.891979
# Iteration 41, loss = 0.08548568
# Validation score: 0.889583
# Iteration 42, loss = 0.08179591
# Validation score: 0.891042
# Iteration 43, loss = 0.07911534
# Validation score: 0.888229
# Iteration 44, loss = 0.07632201
# Validation score: 0.893646
# Iteration 45, loss = 0.07070742
# Validation score: 0.893750
# Iteration 46, loss = 0.06381280
# Validation score: 0.887708
# Iteration 47, loss = 0.07053305
# Validation score: 0.891146
# Iteration 48, loss = 0.07128969
# Validation score: 0.887604
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
test_predictions = model_sklearn.predict(test_images)
test_acc_sklearn = accuracy_score(test_labels, test_predictions)

print('\nTest accuracy:', test_acc_sklearn)
# Out:
# Test accuracy: 0.887

# %%
print("\nClassifications Report:\n", classification_report(test_labels, test_predictions))

predictions_proba = model_sklearn.predict_proba(test_images)
# Out:
# Classifications Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1000
#            1       0.97      0.97      0.97      1000
#            2       0.79      0.82      0.80      1000
#            3       0.88      0.90      0.89      1000
#            4       0.79      0.86      0.82      1000
#            5       0.97      0.96      0.97      1000
#            6       0.79      0.62      0.69      1000
#            7       0.93      0.97      0.95      1000
#            8       0.97      0.97      0.97      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
predictions_sklearn = model_sklearn.predict_proba(test_images)
print(predictions_sklearn[0])  

print("Predicted label for first image : ", np.argmax(predictions_sklearn[0]))

print("Actual label for first image : ", test_labels.iloc[0])
# Out:
# [5.64442525e-11 5.47828768e-11 7.58079918e-11 2.97675609e-11
#  5.51112178e-10 8.91384002e-07 1.49251292e-09 3.56008471e-04
#  1.01933157e-09 9.99643097e-01]
# Predicted label for first image :  9
# Actual label for first image :  9

# %%
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label.iloc[i], img.iloc[i].values.reshape(28, 28) 
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"{class_names[predicted_label]} {100*np.max(predictions_array):.2f}% ({class_names[true_label]})", color=color)

def plot_value_array(i, predictions_array, true_label):
    true_label = true_label.iloc[i] 
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#7777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 1
plt.figure(figsize=(6,3))
plt.subplot(1, 2, 1)
plot_image(i, predictions_sklearn[i] ,test_labels, test_images)
plt.subplot(1, 2, 2)
plot_value_array(i,predictions_sklearn[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

num_rows = 5
num_cols = 4
num_images = num_rows * num_cols

correct_predictions = [np.argmax(predictions_sklearn[i]) == test_labels.iloc[i] for i in range(num_images)]

average_accuracy = np.mean(correct_predictions) * 100

plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plot_image(i, predictions_sklearn[i], test_labels, test_images)
    border_color = 'green' if correct_predictions[i] else 'red'
    plt.gca().patch.set_edgecolor(border_color)
    plt.gca().patch.set_linewidth(3)

    plt.subplot(num_rows, 2 * num_cols, 2 * i + 2)
    plot_value_array(i,predictions_sklearn[i], test_labels)

plt.suptitle(f'Akurasi Rata-rata: {average_accuracy:.2f}%')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

n_samples = 10000

df_test = pd.DataFrame({
    'Target': test_labels,  
    'Predicted': np.argmax(predictions_sklearn, axis=1),
    'Proba_0': predictions_sklearn[:, 0],
    'Proba_1': predictions_sklearn[:, 1]
})

df_test['Proba_0'] = df_test['Proba_0'] / (df_test['Proba_0'] + df_test['Proba_1'])
df_test['Proba_1'] = 1- df_test['Proba_0']

for i in range(1, 28*28 + 1):
    df_test[f'pixel{i}'] = np.random.randint(0, 256, n_samples)

df_plot = df_test.sample(16, random_state=84).copy()

fig, ax = plt.subplots(4, 4, figsize=(10, 10))
rata2_accuracy = (df_test['Target'] == df_test['Predicted']).mean() * 100

for i, axi in enumerate(ax.flat):
    p0 = df_plot['Proba_0'].values[i]
    p1 = df_plot['Proba_1'].values[i]

    predicted_class = df_plot['Predicted'].values[i]
    prediction_probability = max(p0, p1) * 100
    true_class = df_plot['Target'].values[i]
    pixels = df_plot[[f'pixel{j}' for j in range(1, 28*28 + 1)]].values[i].reshape(28, 28)
    axi.imshow(pixels, cmap='viridis')
    axi.set(xticks=[], yticks=[],
            xlabel=f"True: {true_class}\nPred: {predicted_class}\nProb: {prediction_probability:.2f}%")
    edge_color = 'green' if predicted_class == true_class else 'red'
    for spine in axi.spines.values():
        spine.set_edgecolor(edge_color)
        spine.set_linewidth(3)

fig.suptitle(f'Contoh gambar yang diklasifikasikan dari set pengujian\n'
             f'Batas hijau: klasifikasi benar\nAkurasi Keseluruhan: {rata2_accuracy:.2f}%')
fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label.iloc[i], img.iloc[i].values.reshape(28, 28)

    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap='gray') 
    
    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"{class_names[predicted_label]} {100*np.max(predictions_array):.2f}% ({class_names[true_label]})", color=color)

    
def plot_value_array(i, predictions_array, true_label):
    true_label = true_label.iloc[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#77777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

i = 19
plt.figure(figsize=(6, 3))

plt.subplot(1, 2, 1)
plot_image(i, predictions_sklearn[i], test_labels, test_images)

plt.subplot(1, 2, 2)
plot_value_array(i, predictions_sklearn[i], test_labels)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def save_image_only(i, true_label, img):
    img = img.iloc[i].values.reshape(28, 28)
    
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.savefig(f"image_only_{i}.jpeg", bbox_inches='tight', pad_inches=0)
    plt.close()

    i = 19
    save_image_only(i, test_labels, test_images)

# %%
import pandas as pd
data={
    'Model': ['TensorFlow', 'Scikit-Learn'],
    'Accuracy': [test_acc_tf, test_acc_sklearn],
    'Architecture': ['Neural Network (2 hiddenlayers)', 'MLP (2 hidden layer)'], 
    'Early Stopping': ['Yes', 'Yes']
}

comparison_df = pd.DataFrame(data)

best_model = comparison_df.loc[comparison_df['Accuracy'].idxmax()]

print("Comparison of Model Performance:")
print(comparison_df)

print("\nBest Model Based on Accuracy:")
print(best_model)
# Out:
# Comparison of Model Performance:
#           Model  Accuracy                     Architecture Early Stopping
# 0    TensorFlow    0.8845  Neural Network (2 hiddenlayers)            Yes
# 1  Scikit-Learn    0.8870             MLP (2 hidden layer)            Yes
#
# Best Model Based on Accuracy:
# Model                     Scikit-Learn
# Accuracy                         0.887
# Architecture      MLP (2 hidden layer)
# Early Stopping                     Yes
# Name: 1, dtype: object

# %%
import pickle

with open('best_model.pkl', 'wb') as file:
    pickle.dump(model_sklearn, file)

# %%
# import pickle
# import tensorflow as tf
# #Cara dump h5 jika model tensorflow yang terbaik
# # Menyimpan model TensorFlow
# model_tf.save('best_model_tf.h5')
